# %% [markdown]
# # Weird or strange plots created over the course of this project :)

# %% [markdown]
# ![image.png](attachment:99849ae4-4cb2-48af-b4dc-7a2d9c39d58a.png)
#
# ***got caught with jet***

# %% [markdown]
# ![Screenshot 2025-05-01 at 9.39.24 PM.png](attachment:3d60a0c8-b602-4454-a2f8-f9a7a57ffbac.png)

# %% [markdown]
# ![Screenshot 2025-05-01 at 9.40.05 PM.png](attachment:082a16e9-f3a9-446f-aca4-a259e051b124.png)

# %% [markdown]
# ***Best plot right here***
