# %% [markdown]
# # ☀️ SP2025-FP02-solar-flares ☀️

# %% [markdown]
# ### Erica Maebius (emaebius) and Anna Williams (ag-williams)

# %% [markdown]
# ## I. Introduction

# %% [markdown]
# Solar flares, caused by the tangling of the sun's magnetic field, eject large amounts of electromagnetic energy into space. Although Earth's atmosphere protects us from the majority of emitted charged particles and X-rays, solar flares can disrupt the ionosphere, impacting radio wave propagation around the world. This can be problematic for satellite and air traffic communications. We will analyze a report, "Super-Intense Geomagnetic Storm on 10–11 May 2024: Possible Mechanisms and Impacts" and attempt to recreate their charts based on the open source data provided. This project allows us to test our analystic ability and create our own version and interpretation of a major space weather event in the form of a formal report.

# %% [markdown]
# ## II. Context

# %% [markdown]
# ### What causes solar flares?
# - The equatorial and polar areas of the Sun rotate at different rates, which causes the Sun's magnetic fields to tangle. [1]
# - At these tangled spots, the localized magnetic field can become so strong that they twist away from the Sun's surface, ejecting large amounts of radiation. [1]
# - These ejections create solar storms. [1]
# - Solar storms come in a couple of different flavors: [2]
#     - Solar flares, which are an intense burst of electromagnetic radiation. These range from A (weakest), B, C, M, X(strongest). These classes are on a logarithmic scale. Within each class, they are further subdivided into 1-9.
#         - Energy from flares travel at the speed of light!
#     - Radiation storms are explosions of electrically charged particals (protons and electrons).
#     - Coronal mass ejections (CMEs) occur when plasma (electrically charged gas) erupts from the sun. These are much slower than solar flares and radiation storms but have a much larger impact on Earth. They can induce electrical currents and damage electrical equipment and heat up the atmosphere, increasing drag on orbiting satellites.
# - Major solar flares can prove a risk to high altitude flights due to exposure to high-energy particles.

# %% [markdown]
# ### May 10-11 2024 Geomagnetic Storm
#
# ***"This is an unusual and potentially historic event."***
#
#      - Clinton Wallace, Director, NOAA’s Space Weather Prediction Center [4]
#
# - Biggest solar storm to hit Earth in 20 years
# - The Sun neared its peak solar activity period (solar maximum) in its 11-year solar cycle
# - Released several significant solar flares, stretching our protective atmosphere to its limits
#
# ![image.png](attachment:85fd03e4-8cde-4f8b-b714-6762e449af02.png)
#
# Image 1: Space Weather Effects on Earth [5]

# %% [markdown]
# ## III. Data
# Data used in this report:
# - [DSCOVR solar wind and IMF](https://www.ngdc.noaa.gov/dscovr/portal/index.html#/)
# - [Magnetic field (Bz and By) data from the GOES-18](https://cdaweb.gsfc.nasa.gov/pub/data/goes/goes18/)
# - [TEC map data](http://millstonehill.haystack.mit.edu/listExperiments?isGlobal=on%26categories=17%26instruments=8000%26showDefault=on%26start_date_0=1950-01-01%26start_date_1=00%3A00%3A00%26end_date_0=2024-12-31%26end_date_1=23%3A59%3A59)
# - [Data from magnetometers, VLF receivers, and Ionosonde](https://zenodo.org/records/12623351)
#
# This data encompassed a broad range of information representative of the impacts of the solar storm recorded from both instruments in space and Earth. The Deep Space Climate Observatory (DSCOVR), a NASA satellite at Lagrange point 1 (L1), recorded solar wind and IMF data using its magnetometer and Faraday cup. The Bz and By magnetic field data was collected from NOAA's Geostationary Operational Environmental Satellites (GOES-18). MIT's Millstone Hill Geospace Facility provided the TEC map data from the worldwide GNSS receiver network. Finally, the magnetometers, VLF receivers and Ionosonde data was available through the Indian Institute of Geomagnetism.

# %% [markdown]
# ## IV. Results

# %% [markdown]
# ## V. Challenges

# %% [markdown]
# ## VI. Conclusion

# %% [markdown]
# ## Works Cited

# %% [markdown]
# [1] https://scied.ucar.edu/video/sun-magnetic-field-rotate-tangle-movie
#
# [2] https://science.nasa.gov/sun/solar-storms-and-flares/
#
# [3] https://agupubs.onlinelibrary.wiley.com/doi/full/10.1029/2024SW004126#swe21812-bib-0020
#
# [4] https://www.noaa.gov/stories/strong-geomagnetic-storm-reaches-earth-continues-through-weekend
#
# [5] https://www.esa.int/Space_Safety/Space_weather/The_May_2024_solar_storm_your_questions_answered
#
# **[6] https://agupubs.onlinelibrary.wiley.com/doi/full/10.1029/2024SW004126#swe21812-bib-0020**
